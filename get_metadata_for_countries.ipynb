# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
import pycountry

# %% [markdown]
# # Acquiring Most Common Languages per Country

# %%
# url of a website containg most common languages per country
language_url = "https://www.infoplease.com/world/countries/languages-spoken-in-each-country-of-the-world"

# %%
# get html page
page = requests.get(language_url)

# transform to soup object
soup = BeautifulSoup(page.content, 'html.parser')
    
# find the table with all information (right, top of wikipedia article)
table = soup.find('table')

# get all the rows of the table, discard the header line
rows = table.find_all("tr")[1:]

# %%
country_languages = {}

# regular expressions
find_country_regex = r">.*<"
remove_bracket_regex = r'\([^\]]*\)'

# extract countries and corresponding languages
for row in rows:
    # get the country names
    country = str(re.findall(find_country_regex, str(row.findChild("a")))[0][1:-1])
    # remove hexadecimals
    country = country.encode('ascii', errors='ignore').decode("UTF-8")
    # remove brackets
    country = re.sub(remove_bracket_regex, "", country)
    # replace st. by sant
    country = country.replace("St.", "Saint")
    #country = country.decode('utf8').encode('ascii', errors='ignore')
    # contains the whole row of one country
    temp_list = str(row.findAll('p')[1])[3:-4].split(",")
    # extract only the language names
    languages = []
    for language in temp_list:
        # only get 3 languages
        if len(languages) < 3:
            languages.append(re.findall(r"([^\s]+)", language)[0])
    # add to dictionary
    country_languages[country] = languages

# %%
# fix wrong words
remove_words = ["other", "and", "widely", "tribal", "24", "60", "declining", "Qazaq)", 
                "multilingual", "indigenous", "which", "small", "unspecified", "but", "universal",
               "regular", "120", "the", "only", "one", "taught", "used", "local", "some", "numerous", 
                "a", "Standard", "based"]

for country, language in country_languages.items():
    for illegal_word in remove_words:
        if illegal_word in country_languages[country]:
            country_languages[country].remove(illegal_word)
################################################################################################
# fix country names for pycountry
replace_country_names_dic = {"Congo, Democratic Republic of the":"Congo, The Democratic Republic of the",     
                        "Congo, Republic of": "Congo",
                        "Cape Verde":"Cabo Verde",
                        "Palestinian State ":"Palestine, State of",
                        "East Timor":"Timor-Leste",
                        "Korea, North":"Korea, Democratic People's Republic of",
                        "Korea, South":"Korea, Republic of",
                        "Laos":"Lao People's Democratic Republic",
                        "So Tom and Prncipe":"Sao Tome and Principe",
                        "Cte d'Ivoire":"Côte d'Ivoire"}
# since we cannot change the size of the dictionary withing a loop, save the ones that are supposed
# to be deleted and their replacements
to_delete = []
to_add = {}
# depending on replace_country_names_dic, look at what to replace and what to replace with
for country, language_list in country_languages.items():
    if country in replace_country_names_dic.keys():
        to_add[replace_country_names_dic[country]] = language_list
        to_delete.append(country)
        
# delete old names
for country in to_delete:
    del country_languages[country]
    
# add new ones
country_languages = {**country_languages, **to_add}

################################################################################################
# manual fixes
country_languages["China"].extend(["Mandarin", "Chinese"])
country_languages["Western Sahara"].extend(["Arabic"])
country_languages["Philippines"].extend(["English"])
del country_languages["Kosovo"] # not included in pycountry

# %%
country_languages
# Out:
# {'Afghanistan': ['Afghan', 'Pashto', 'Uzbek'],
#  'Albania': ['Albanian', 'Greek'],
#  'Algeria': ['Arabic', 'French', 'Berber'],
#  'Andorra': ['Catalan', 'French', 'Castilian'],
#  'Angola': ['Portuguese', 'Umbundu', 'Kikongo'],
#  'Antigua and Barbuda': ['English', 'Antiguan'],
#  'Argentina': ['Spanish', 'Italian', 'English'],
#  'Armenia': ['Armenian', 'Kurdish'],
#  'Australia': ['English', 'Mandarin', 'Arabic'],
#  'Austria': ['German', 'Turkish', 'Serbian'],
#  'Azerbaijan': ['Azerbaijani', 'Russian', 'Armenian'],
#  'Bahamas': ['Azerbaijani', 'Russian', 'Armenian'],
#  'Bahrain': ['Arabic', 'English', 'Farsi'],
#  'Bangladesh': ['Bangla', 'also'],
#  'Barbados': ['English', 'Bajan'],
#  'Belarus': ['Russian', 'Belarusian'],
#  'Belgium': ['Dutch', 'French', 'German'],
#  'Belize': ['English', 'Spanish', 'Creole'],
#  'Benin': ['French', 'Fon'],
#  'Bhutan': ['Sharchhopka', 'Dzongkha', 'Lhotshamkha'],
#  'Bolivia': ['Spanish', 'Quechua', 'Aymara'],
#  'Bosnia and Herzegovina': ['Bosnian', 'Serbian', 'Croatian'],
#  'Botswana': ['Setswana', 'Sekalanga', 'Shekgalagadi'],
#  'Brazil': ['Portuguese'],
#  'Brunei': ['Malay', 'English', 'Chinese'],
#  'Bulgaria': ['Bulgarian', 'Turkish', 'Romani'],
#  'Burkina Faso': ['French', 'native'],
#  'Burundi': ['Kirundi', 'French'],
#  'Cambodia': ['Khmer'],
#  'Cameroon': ['English', 'French'],
#  'Canada': ['English', 'French', 'Punjabi'],
#  'Central African Republic': ['French', 'Sangho'],
#  'Chad': ['French', 'Arabic', 'Sara'],
#  'Chile': ['Spanish', 'English'],
#  'China': ['Yue', 'Mandarin', 'Chinese'],
#  'Colombia': ['Spanish'],
#  'Comoros': ['Arabic', 'French', 'Shikomoro'],
#  'Costa Rica': ['Spanish', 'English'],
#  'Croatia': ['Croatian', 'Serbian'],
#  'Cuba': ['Spanish'],
#  'Cyprus': ['Greek', 'Turkish', 'English'],
#  'Czech Republic': ['Greek', 'Turkish', 'English'],
#  'Denmark': ['Danish', 'Faroese', 'Greenlandic'],
#  'Djibouti': ['French', 'Arabic', 'Somali'],
#  'Dominica': ['English', 'French'],
#  'Dominican Republic': ['Spanish'],
#  'Ecuador': ['Spanish', 'Quechua'],
#  'Egypt': ['Arabic', 'Arabic', 'English'],
#  'El Salvador': ['Spanish', 'Nawat'],
#  'Equatorial Guinea': ['Spanish', 'Bubi'],
#  'Eritrea': ['Tigrinya', 'Arabic', 'English'],
#  'Estonia': ['Estonian', 'Russian', 'Ukrainian'],
#  'Eswatini': ['English', 'siSwati'],
#  'Ethiopia': ['Oromo', 'Amharic', 'Somali'],
#  'Fiji': ['English', 'Fijian', 'Hindustani'],
#  'Finland': ['Finnish', 'Swedish', 'Russian'],
#  'France': ['French', 'Breton'],
#  'Gabon': ['French', 'Fang', 'Myene'],
#  'Gambia': ['French', 'Fang', 'Myene'],
#  'Georgia': ['Georgian', 'Azeri', 'Armenian'],
#  'Germany': ['German'],
#  'Ghana': ['Asante', 'Ewe', 'Fante'],
#  'Greece': ['Greek'],
#  'Grenada': ['English', 'French'],
#  'Guatemala': ['Spanish', 'Maya', "K'iche"],
#  'Guinea': ['French', 'Pular', 'Maninka'],
#  'Guinea-Bissau': ['Crioulo', 'Portuguese', 'Pular'],
#  'Guyana': ['English', 'Guyanese', 'Amerindian'],
#  'Haiti': ['French', 'Creole'],
#  'Honduras': ['Spanish', 'Amerindian'],
#  'Hungary': ['Hungarian', 'English', 'German'],
#  'Iceland': ['Icelandic', 'English', 'Nordic'],
#  'India': ['Hindi', 'Bengali', 'Marathi'],
#  'Indonesia': ['Bahasa', 'modified', 'English'],
#  'Iran': ['Persian', 'Azeri', 'Kurdish'],
#  'Iraq': ['Arabic', 'Kurdish', 'Turkmen'],
#  'Ireland': ['English', 'Irish'],
#  'Israel': ['Hebrew', 'Arabic', 'English'],
#  'Italy': ['Italian', 'German', 'French'],
#  'Jamaica': ['English', 'English'],
#  'Japan': ['Japanese'],
#  'Jordan': ['Arabic', 'English'],
#  'Kazakhstan': ['Kazakh', 'Russian'],
#  'Kenya': ['English', 'Kiswahili'],
#  'Kiribati': ['I-Kiribati', 'English'],
#  'Kuwait': ['Arabic', 'English'],
#  'Kyrgyzstan': ['Kyrgyz', 'Uzbek', 'Russian'],
#  'Latvia': ['Latvian', 'Russian'],
#  'Lebanon': ['Arabic', 'French', 'English'],
#  'Lesotho': ['Sesotho', 'English', 'Zulu'],
#  'Liberia': ['English'],
#  'Libya': ['Arabic', 'Italian', 'English'],
#  'Liechtenstein': ['German', 'Italian', 'Turkish'],
#  'Lithuania': ['Lithuanian', 'Russian', 'Polish'],
#  'Luxembourg': ['Luxembourgish', 'Portuguese', 'French'],
#  'Madagascar': ['French', 'Malagasy', 'English'],
#  'Malawi': ['English', 'Chewa', 'Lambya'],
#  'Malaysia': ['Bahasa', 'English', 'Chinese'],
#  'Maldives': ['Dhivehi', 'dialect', 'script'],
#  'Mali': ['French', 'Bambara', 'Peuhl/Foulfoulbe'],
#  'Malta': ['Maltese', 'English'],
#  'Marshall Islands': ['Marshallese'],
#  'Mauritania': ['Arabic', 'Pular', 'Soninke'],
#  'Mauritius': ['Creole', 'Bhojpuri', 'French'],
#  'Mexico': ['Spanish', 'Spanish'],
#  'Micronesia': ['Spanish', 'Spanish'],
#  'Moldova': ['Moldovan/Romanian', 'Russian'],
#  'Monaco': ['French', 'English', 'Italian'],
#  'Mongolia': ['Mongolian', 'Turkic', 'Russian'],
#  'Montenegro': ['Serbian', 'Montenegrin', 'Bosnian'],
#  'Morocco': ['Arabic', 'Berber', 'Tachelhit'],
#  'Mozambique': ['Makhuwa', 'Portuguese', 'Tsonga'],
#  'Myanmar': ['Makhuwa', 'Portuguese', 'Tsonga'],
#  'Namibia': ['Oshiwambo', 'Nama/Damara', 'Kavango'],
#  'Nauru': ['Nauruan', 'English'],
#  'Nepal': ['Nepali', 'Maithali', 'Bhojpuri'],
#  'Netherlands': ['Dutch'],
#  'New Zealand': ['English', 'Maori', 'Samoan'],
#  'Nicaragua': ['Spanish', 'Miskito', 'Mestizo'],
#  'Niger': ['French', 'Hausa', 'Djerma'],
#  'Nigeria': ['English', 'Hausa', 'Yoruba'],
#  'North Macedonia': ['Macedonian', 'Albanian', 'Turkish'],
#  'Norway': ['Bokmal', 'Nynorsk'],
#  'Oman': ['Arabic', 'English', 'Baluchi'],
#  'Pakistan': ['Punjabi', 'Sindhi', 'Saraiki'],
#  'Palau': ['Palauan', 'English'],
#  'Panama': ['Spanish', 'Buglere'],
#  'Papua New Guinea': ['Tok', 'English', 'Hiri'],
#  'Paraguay': ['Spanish', 'only'],
#  'Peru': ['Spanish', 'Quechua', 'Aymara'],
#  'Philippines': ['Cebuano', 'Ilocano', 'English'],
#  'Poland': ['Polish', 'Silesian'],
#  'Portugal': ['Portuguese', 'Mirandese'],
#  'Qatar': ['Arabic', 'English'],
#  'Romania': ['Romanian', 'Hungarian', 'Romani'],
#  'Russia': ['Russian', 'Tatar', 'Chechen'],
#  'Rwanda': ['Kinyarwanda', 'French'],
#  'Saint Kitts and Nevis': ['Sinhala', 'Tamil', 'English'],
#  'Saint Lucia': ['Sinhala', 'Tamil', 'English'],
#  'Saint Vincent and the Grenadines': ['Sinhala', 'Tamil', 'English'],
#  'Samoa': ['Samoan', 'Somoan/English', 'English'],
#  'San Marino': ['Italian'],
#  'Saudi Arabia': ['Arabic'],
#  'Senegal': ['French', 'Wolof', 'Pular'],
#  'Serbia': ['Serbian', 'Hungarian', 'Bosnian'],
#  'Seychelles': ['Seychellois', 'English', 'French'],
#  'Sierra Leone': ['English', 'Mende'],
#  'Singapore': ['English', 'Mandarin'],
#  'Slovakia': ['Slovak', 'Hungarian', 'Roma'],
#  'Slovenia': ['Slovene', 'Serbo-Croatian'],
#  'Solomon Islands': ['Melanesian', 'English'],
#  'Somalia': ['Somali', 'according', 'Arabic'],
#  'South Africa': ['isiZulu', 'isiXhosa', 'Afrikaans'],
#  'South Sudan': ['English', 'Arabic', 'regional'],
#  'Spain': ['Castilian', 'Catalan'],
#  'Sri Lanka': ['Sinhala', 'Tamil', 'English'],
#  'Sudan': ['Arabic', 'English', 'Nubian'],
#  'Suriname': ['Dutch', 'English', 'Sranang'],
#  'Sweden': ['Swedish'],
#  'Switzerland': ['German', 'French', 'Italian'],
#  'Syria': ['Arabic', 'Kurdish', 'Armenian'],
#  'Taiwan': ['Mandarin', 'Taiwanese', 'Hakka'],
#  'Tajikistan': ['Tajik', 'Uzbek', 'Kyrgyz'],
#  'Tanzania': ['Kiswahili', 'Kiunguja', 'English'],
#  'Thailand': ['Thai', 'Thai'],
#  'Togo': ['French', 'Ewe'],
#  'Tonga': ['Tongan', 'Tongan', 'English'],
#  'Trinidad and Tobago': ['English', 'Trinidadian', 'Tobagonian'],
#  'Tunisia': ['Arabic', 'French'],
#  'Turkey': ['Turkish', 'Kurdish'],
#  'Turkmenistan': ['Turkmen', 'Russian', 'Uzbek'],
#  'Tuvalu': ['Tuvaluan', 'English', 'Samoan'],
#  'Uganda': ['English'],
#  'Ukraine': ['Ukrainian', 'Russian'],
#  'United Arab Emirates': ['Arabic', 'English', 'Hindi'],
#  'United Kingdom': ['English'],
#  'United States': ['English', 'Spanish', 'Chinese'],
#  'Uruguay': ['Spanish'],
#  'Uzbekistan': ['Uzbek', 'Russian', 'Tajik'],
#  'Vanuatu': ['Bislama', 'English'],
#  'Vatican City': ['Italian', 'Latin', 'French'],
#  'Venezuela': ['Spanish'],
#  'Vietnam': ['Vietnamese', 'English'],
#  'Western Sahara': ['Hassaniya', 'Moroccan', 'Arabic'],
#  'Yemen': ['Arabic'],
#  'Zambia': ['Bemba', 'Nyanja', 'Tonga'],
#  'Zimbabwe': ['Shona', 'Ndebele', 'second'],
#  'Cabo Verde': ['English', 'French', 'Punjabi'],
#  'Congo, The Democratic Republic of the': ['French', 'Lingala', 'Kingwana'],
#  'Congo': ['French', 'Lingala', 'Kingwana'],
#  "Côte d'Ivoire": ['French'],
#  'Timor-Leste': ['Spanish'],
#  "Korea, Democratic People's Republic of": ['Korean'],
#  'Korea, Republic of': ['Korean', 'English', 'junior'],
#  "Lao People's Democratic Republic": ['Lao', 'French', 'English'],
#  'Palestine, State of': ['Palauan', 'English'],
#  'Sao Tome and Principe': ['Portuguese', 'Forro', 'Cabo']}

# %% [markdown]
# # Acquiring Most Common Religions per Country

# %%
# url of a website containg most common languages per country
language_url = "https://www.infoplease.com/world/social-statistics/world-religions"
religions_permitted = ["Islam", "Roman Catholic", "Jewish", "Buddhist", "Protestant", "Christian", 
                       "Orthodox", "Buddhism", "Hindu", "Anglican", "Catholic", "Evangelical", "Protestant",
                      "Church of Tuvalu"]

# %%
# get html page
page = requests.get(language_url)

# transform to soup object
soup = BeautifulSoup(page.content, 'html.parser')
    
# find the table with all information (right, top of wikipedia article)
table = soup.find('table')

# get all the rows of the table, discard the header line
rows = table.find_all("tr")

# %%
country_religions = {}

# regular expressions
find_country_regex = r">.*<"
find_country_regex_alt = r"<td>(.*?)</td>"
remove_bracket_regex = r"\([^\]]*\)"
get_percentage_regex = r"/d{,3}\%"
# extract countries and corresponding languages
for row in rows:
    # get the country names depending how the text is embedded in the html
    if row.findChild("a"):

        country = str(re.findall(find_country_regex, str(row.findChild("a")))[0][1:-1])
    else:
        country = str(re.findall(find_country_regex_alt, str(row))[0])
    
    # remove hexadecimals
    country = country.encode('ascii', errors='ignore').decode("UTF-8")
    # remove brackets
    country = re.sub(remove_bracket_regex, "", country)
    # replace st. by sant
    country = country.replace("St.", "Saint")
    # removing trailing whitespace
    country = country.rstrip()
    
    # fill dictionary
    country_religions[country] = []
    for r in religions_permitted:
        if r in str(row):
            country_religions[country].append(r)

# %%
# fix country names for pycountry
replace_country_names_dic = {"Congo, Democratic Republic of the":"Congo, The Democratic Republic of the",     
                        "Congo, Republic of": "Congo",
                        "Cape Verde":"Cabo Verde",
                        "Palestinian State":"Palestine, State of",
                        "East Timor":"Timor-Leste",
                        "Korea, North":"Korea, Democratic People's Republic of",
                        "Korea, South":"Korea, Republic of",
                        "Laos":"Lao People's Democratic Republic",
                        "So Tom and Prncipe":"Sao Tome and Principe",
                        "Cte d'Ivoire":"Côte d'Ivoire",
                        "Macedonia":"North Macedonia",
                        "Swaziland":"Eswatini"}
# since we cannot change the size of the dictionary withing a loop, save the ones that are supposed
# to be deleted and their replacements
to_delete = []
to_add = {}

# depending on replace_country_names_dic, look at what to replace and what to replace with
for country, religion_list in country_religions.items():
    if country in replace_country_names_dic.keys():
        to_add[replace_country_names_dic[country]] = religion_list
        to_delete.append(country)
        
# delete old names
for country in to_delete:
    del country_religions[country]
    
# add new ones
country_religions = {**country_religions, **to_add}

# manual addition
country_religions["South Sudan"] = ["Christian", "Islam"]

# %% [markdown]
# # Adding Languages and Religions to Dataframe

# %%
# for creating a df
country_name_list = []
country_alpha_2_list = []
country_alpha_3_list = []
languages_list = []
religion_list = []

for country, language_list in country_languages.items():
    # use the pycountry package to obtain the common names, and the alpha2 and alpha3 abbreviations
    pycountry_object = pycountry.countries.search_fuzzy(country)[0]
    country_name_list.append(pycountry_object.name)
    country_alpha_2_list.append(pycountry_object.alpha_2)
    country_alpha_3_list.append(pycountry_object.alpha_3)
    languages_list.append(language_list)
    religion_list.append(country_religions[country])
    
# create it
country_df = df = pd.DataFrame(list(zip(country_name_list, country_alpha_2_list, country_alpha_3_list, 
                                             languages_list, religion_list)), 
                                   columns =["name", "alpha_2", "alpha_3", "languages", "religions"]) 

# save it
country_df.to_pickle("countries.pkl")

# display it
country_df
# Out:
#                                        name alpha_2 alpha_3  \
# 0                               Afghanistan      AF     AFG
# 1                                   Albania      AL     ALB
# 2                                   Algeria      DZ     DZA
# 3                                   Andorra      AD     AND
# 4                                    Angola      AO     AGO
# 5                       Antigua and Barbuda      AG     ATG
# 6                                 Argentina      AR     ARG
# 7                                   Armenia      AM     ARM
# 8                                 Australia      AU     AUS
# 9                                   Austria      AT     AUT
# 10                               Azerbaijan      AZ     AZE
# 11                                  Bahamas      BS     BHS
# 12                                  Bahrain      BH     BHR
# 13                               Bangladesh      BD     BGD
# 14                                 Barbados      BB     BRB
# 15                                  Belarus      BY     BLR
# 16                                  Belgium      BE     BEL
# 17                                   Belize      BZ     BLZ
# 18                                    Benin      BJ     BEN
# 19                                   Bhutan      BT     BTN
# 20          Bolivia, Plurinational State of      BO     BOL
# 21                   Bosnia and Herzegovina      BA     BIH
# 22                                 Botswana      BW     BWA
# 23                                   Brazil      BR     BRA
# 24                        Brunei Darussalam      BN     BRN
# 25                                 Bulgaria      BG     BGR
# 26                             Burkina Faso      BF     BFA
# 27                                  Burundi      BI     BDI
# 28                                 Cambodia      KH     KHM
# 29                                 Cameroon      CM     CMR
# 30                                   Canada      CA     CAN
# 31                 Central African Republic      CF     CAF
# 32                                     Chad      TD     TCD
# 33                                    Chile      CL     CHL
# 34                                    China      CN     CHN
# 35                                 Colombia      CO     COL
# 36                                  Comoros      KM     COM
# 37                               Costa Rica      CR     CRI
# 38                                  Croatia      HR     HRV
# 39                                     Cuba      CU     CUB
# 40                                   Cyprus      CY     CYP
# 41                                  Czechia      CZ     CZE
# 42                                  Denmark      DK     DNK
# 43                                 Djibouti      DJ     DJI
# 44                                 Dominica      DM     DMA
# 45                       Dominican Republic      DO     DOM
# 46                                  Ecuador      EC     ECU
# 47                                    Egypt      EG     EGY
# 48                              El Salvador      SV     SLV
# 49                        Equatorial Guinea      GQ     GNQ
# 50                                  Eritrea      ER     ERI
# 51                                  Estonia      EE     EST
# 52                                 Eswatini      SZ     SWZ
# 53                                 Ethiopia      ET     ETH
# 54                                     Fiji      FJ     FJI
# 55                                  Finland      FI     FIN
# 56                                   France      FR     FRA
# 57                                    Gabon      GA     GAB
# 58                                   Gambia      GM     GMB
# 59                                  Georgia      GE     GEO
# 60                                  Germany      DE     DEU
# 61                                    Ghana      GH     GHA
# 62                                   Greece      GR     GRC
# 63                                  Grenada      GD     GRD
# 64                                Guatemala      GT     GTM
# 65                                   Guinea      GN     GIN
# 66                            Guinea-Bissau      GW     GNB
# 67                                   Guyana      GY     GUY
# 68                                    Haiti      HT     HTI
# 69                                 Honduras      HN     HND
# 70                                  Hungary      HU     HUN
# 71                                  Iceland      IS     ISL
# 72                                    India      IN     IND
# 73                                Indonesia      ID     IDN
# 74                Iran, Islamic Republic of      IR     IRN
# 75                                     Iraq      IQ     IRQ
# 76                                  Ireland      IE     IRL
# 77                                   Israel      IL     ISR
# 78                                    Italy      IT     ITA
# 79                                  Jamaica      JM     JAM
# 80                                    Japan      JP     JPN
# 81                                   Jordan      JO     JOR
# 82                               Kazakhstan      KZ     KAZ
# 83                                    Kenya      KE     KEN
# 84                                 Kiribati      KI     KIR
# 85                                   Kuwait      KW     KWT
# 86                               Kyrgyzstan      KG     KGZ
# 87                                   Latvia      LV     LVA
# 88                                  Lebanon      LB     LBN
# 89                                  Lesotho      LS     LSO
# 90                                  Liberia      LR     LBR
# 91                                    Libya      LY     LBY
# 92                            Liechtenstein      LI     LIE
# 93                                Lithuania      LT     LTU
# 94                               Luxembourg      LU     LUX
# 95                               Madagascar      MG     MDG
# 96                                   Malawi      MW     MWI
# 97                                 Malaysia      MY     MYS
# 98                                 Maldives      MV     MDV
# 99                                     Mali      ML     MLI
# 100                                   Malta      MT     MLT
# 101                        Marshall Islands      MH     MHL
# 102                              Mauritania      MR     MRT
# 103                               Mauritius      MU     MUS
# 104                                  Mexico      MX     MEX
# 105         Micronesia, Federated States of      FM     FSM
# 106                    Moldova, Republic of      MD     MDA
# 107                                  Monaco      MC     MCO
# 108                                Mongolia      MN     MNG
# 109                              Montenegro      ME     MNE
# 110                                 Morocco      MA     MAR
# 111                              Mozambique      MZ     MOZ
# 112                                 Myanmar      MM     MMR
# 113                                 Namibia      NA     NAM
# 114                                   Nauru      NR     NRU
# 115                                   Nepal      NP     NPL
# 116                             Netherlands      NL     NLD
# 117                             New Zealand      NZ     NZL
# 118                               Nicaragua      NI     NIC
# 119                                 Nigeria      NG     NGA
# 120                                 Nigeria      NG     NGA
# 121                         North Macedonia      MK     MKD
# 122                                  Norway      NO     NOR
# 123                                    Oman      OM     OMN
# 124                                Pakistan      PK     PAK
# 125                                   Palau      PW     PLW
# 126                                  Panama      PA     PAN
# 127                        Papua New Guinea      PG     PNG
# 128                                Paraguay      PY     PRY
# 129                                    Peru      PE     PER
# 130                             Philippines      PH     PHL
# 131                                  Poland      PL     POL
# 132                                Portugal      PT     PRT
# 133                                   Qatar      QA     QAT
# 134                                 Romania      RO     ROU
# 135                      Russian Federation      RU     RUS
# 136                                  Rwanda      RW     RWA
# 137                   Saint Kitts and Nevis      KN     KNA
# 138                             Saint Lucia      LC     LCA
# 139        Saint Vincent and the Grenadines      VC     VCT
# 140                                   Samoa      WS     WSM
# 141                              San Marino      SM     SMR
# 142                            Saudi Arabia      SA     SAU
# 143                                 Senegal      SN     SEN
# 144                                  Serbia      RS     SRB
# 145                              Seychelles      SC     SYC
# 146                            Sierra Leone      SL     SLE
# 147                               Singapore      SG     SGP
# 148                                Slovakia      SK     SVK
# 149                                Slovenia      SI     SVN
# 150                         Solomon Islands      SB     SLB
# 151                                 Somalia      SO     SOM
# 152                            South Africa      ZA     ZAF
# 153                             South Sudan      SS     SSD
# 154                                   Spain      ES     ESP
# 155                               Sri Lanka      LK     LKA
# 156                                   Sudan      SD     SDN
# 157                                Suriname      SR     SUR
# 158                                  Sweden      SE     SWE
# 159                             Switzerland      CH     CHE
# 160                    Syrian Arab Republic      SY     SYR
# 161               Taiwan, Province of China      TW     TWN
# 162                              Tajikistan      TJ     TJK
# 163            Tanzania, United Republic of      TZ     TZA
# 164                                Thailand      TH     THA
# 165                                    Togo      TG     TGO
# 166                                   Tonga      TO     TON
# 167                     Trinidad and Tobago      TT     TTO
# 168                                 Tunisia      TN     TUN
# 169                                  Turkey      TR     TUR
# 170                            Turkmenistan      TM     TKM
# 171                                  Tuvalu      TV     TUV
# 172                                  Uganda      UG     UGA
# 173                                 Ukraine      UA     UKR
# 174                    United Arab Emirates      AE     ARE
# 175                          United Kingdom      GB     GBR
# 176                           United States      US     USA
# 177                                 Uruguay      UY     URY
# 178                              Uzbekistan      UZ     UZB
# 179                                 Vanuatu      VU     VUT
# 180           Holy See (Vatican City State)      VA     VAT
# 181       Venezuela, Bolivarian Republic of      VE     VEN
# 182                                Viet Nam      VN     VNM
# 183                          Western Sahara      EH     ESH
# 184                                   Yemen      YE     YEM
# 185                                  Zambia      ZM     ZMB
# 186                                Zimbabwe      ZW     ZWE
# 187                              Cabo Verde      CV     CPV
# 188   Congo, The Democratic Republic of the      CD     COD
# 189                                   Congo      CG     COG
# 190                           Côte d'Ivoire      CI     CIV
# 191                             Timor-Leste      TL     TLS
# 192  Korea, Democratic People's Republic of      KP     PRK
# 193                      Korea, Republic of      KR     KOR
# 194        Lao People's Democratic Republic      LA     LAO
# 195                     Palestine, State of      PS     PSE
# 196                   Sao Tome and Principe      ST     STP
#
#                                 languages  \
# 0                 [Afghan, Pashto, Uzbek]
# 1                       [Albanian, Greek]
# 2                [Arabic, French, Berber]
# 3            [Catalan, French, Castilian]
# 4          [Portuguese, Umbundu, Kikongo]
# 5                     [English, Antiguan]
# 6             [Spanish, Italian, English]
# 7                     [Armenian, Kurdish]
# 8             [English, Mandarin, Arabic]
# 9              [German, Turkish, Serbian]
# 10       [Azerbaijani, Russian, Armenian]
# 11       [Azerbaijani, Russian, Armenian]
# 12               [Arabic, English, Farsi]
# 13                         [Bangla, also]
# 14                       [English, Bajan]
# 15                  [Russian, Belarusian]
# 16                [Dutch, French, German]
# 17             [English, Spanish, Creole]
# 18                          [French, Fon]
# 19   [Sharchhopka, Dzongkha, Lhotshamkha]
# 20             [Spanish, Quechua, Aymara]
# 21           [Bosnian, Serbian, Croatian]
# 22    [Setswana, Sekalanga, Shekgalagadi]
# 23                           [Portuguese]
# 24              [Malay, English, Chinese]
# 25           [Bulgarian, Turkish, Romani]
# 26                       [French, native]
# 27                      [Kirundi, French]
# 28                                [Khmer]
# 29                      [English, French]
# 30             [English, French, Punjabi]
# 31                       [French, Sangho]
# 32                 [French, Arabic, Sara]
# 33                     [Spanish, English]
# 34               [Yue, Mandarin, Chinese]
# 35                              [Spanish]
# 36            [Arabic, French, Shikomoro]
# 37                     [Spanish, English]
# 38                    [Croatian, Serbian]
# 39                              [Spanish]
# 40              [Greek, Turkish, English]
# 41              [Greek, Turkish, English]
# 42         [Danish, Faroese, Greenlandic]
# 43               [French, Arabic, Somali]
# 44                      [English, French]
# 45                              [Spanish]
# 46                     [Spanish, Quechua]
# 47              [Arabic, Arabic, English]
# 48                       [Spanish, Nawat]
# 49                        [Spanish, Bubi]
# 50            [Tigrinya, Arabic, English]
# 51         [Estonian, Russian, Ukrainian]
# 52                     [English, siSwati]
# 53               [Oromo, Amharic, Somali]
# 54          [English, Fijian, Hindustani]
# 55            [Finnish, Swedish, Russian]
# 56                       [French, Breton]
# 57                  [French, Fang, Myene]
# 58                  [French, Fang, Myene]
# 59            [Georgian, Azeri, Armenian]
# 60                               [German]
# 61                   [Asante, Ewe, Fante]
# 62                                [Greek]
# 63                      [English, French]
# 64                [Spanish, Maya, K'iche]
# 65               [French, Pular, Maninka]
# 66           [Crioulo, Portuguese, Pular]
# 67        [English, Guyanese, Amerindian]
# 68                       [French, Creole]
# 69                  [Spanish, Amerindian]
# 70           [Hungarian, English, German]
# 71           [Icelandic, English, Nordic]
# 72              [Hindi, Bengali, Marathi]
# 73            [Bahasa, modified, English]
# 74              [Persian, Azeri, Kurdish]
# 75             [Arabic, Kurdish, Turkmen]
# 76                       [English, Irish]
# 77              [Hebrew, Arabic, English]
# 78              [Italian, German, French]
# 79                     [English, English]
# 80                             [Japanese]
# 81                      [Arabic, English]
# 82                      [Kazakh, Russian]
# 83                   [English, Kiswahili]
# 84                  [I-Kiribati, English]
# 85                      [Arabic, English]
# 86               [Kyrgyz, Uzbek, Russian]
# 87                     [Latvian, Russian]
# 88              [Arabic, French, English]
# 89               [Sesotho, English, Zulu]
# 90                              [English]
# 91             [Arabic, Italian, English]
# 92             [German, Italian, Turkish]
# 93          [Lithuanian, Russian, Polish]
# 94    [Luxembourgish, Portuguese, French]
# 95            [French, Malagasy, English]
# 96               [English, Chewa, Lambya]
# 97             [Bahasa, English, Chinese]
# 98             [Dhivehi, dialect, script]
# 99    [French, Bambara, Peuhl/Foulfoulbe]
# 100                    [Maltese, English]
# 101                         [Marshallese]
# 102              [Arabic, Pular, Soninke]
# 103            [Creole, Bhojpuri, French]
# 104                    [Spanish, Spanish]
# 105                    [Spanish, Spanish]
# 106          [Moldovan/Romanian, Russian]
# 107            [French, English, Italian]
# 108          [Mongolian, Turkic, Russian]
# 109       [Serbian, Montenegrin, Bosnian]
# 110           [Arabic, Berber, Tachelhit]
# 111         [Makhuwa, Portuguese, Tsonga]
# 112         [Makhuwa, Portuguese, Tsonga]
# 113     [Oshiwambo, Nama/Damara, Kavango]
# 114                    [Nauruan, English]
# 115          [Nepali, Maithali, Bhojpuri]
# 116                               [Dutch]
# 117              [English, Maori, Samoan]
# 118           [Spanish, Miskito, Mestizo]
# 119               [French, Hausa, Djerma]
# 120              [English, Hausa, Yoruba]
# 121       [Macedonian, Albanian, Turkish]
# 122                     [Bokmal, Nynorsk]
# 123            [Arabic, English, Baluchi]
# 124            [Punjabi, Sindhi, Saraiki]
# 125                    [Palauan, English]
# 126                    [Spanish, Buglere]
# 127                  [Tok, English, Hiri]
# 128                       [Spanish, only]
# 129            [Spanish, Quechua, Aymara]
# 130           [Cebuano, Ilocano, English]
# 131                    [Polish, Silesian]
# 132               [Portuguese, Mirandese]
# 133                     [Arabic, English]
# 134         [Romanian, Hungarian, Romani]
# 135             [Russian, Tatar, Chechen]
# 136                 [Kinyarwanda, French]
# 137             [Sinhala, Tamil, English]
# 138             [Sinhala, Tamil, English]
# 139             [Sinhala, Tamil, English]
# 140     [Samoan, Somoan/English, English]
# 141                             [Italian]
# 142                              [Arabic]
# 143                [French, Wolof, Pular]
# 144         [Serbian, Hungarian, Bosnian]
# 145        [Seychellois, English, French]
# 146                      [English, Mende]
# 147                   [English, Mandarin]
# 148             [Slovak, Hungarian, Roma]
# 149             [Slovene, Serbo-Croatian]
# 150                 [Melanesian, English]
# 151           [Somali, according, Arabic]
# 152        [isiZulu, isiXhosa, Afrikaans]
# 153           [English, Arabic, regional]
# 154                  [Castilian, Catalan]
# 155             [Sinhala, Tamil, English]
# 156             [Arabic, English, Nubian]
# 157             [Dutch, English, Sranang]
# 158                             [Swedish]
# 159             [German, French, Italian]
# 160           [Arabic, Kurdish, Armenian]
# 161          [Mandarin, Taiwanese, Hakka]
# 162                [Tajik, Uzbek, Kyrgyz]
# 163        [Kiswahili, Kiunguja, English]
# 164                          [Thai, Thai]
# 165                         [French, Ewe]
# 166             [Tongan, Tongan, English]
# 167    [English, Trinidadian, Tobagonian]
# 168                      [Arabic, French]
# 169                    [Turkish, Kurdish]
# 170             [Turkmen, Russian, Uzbek]
# 171           [Tuvaluan, English, Samoan]
# 172                             [English]
# 173                  [Ukrainian, Russian]
# 174              [Arabic, English, Hindi]
# 175                             [English]
# 176           [English, Spanish, Chinese]
# 177                             [Spanish]
# 178               [Uzbek, Russian, Tajik]
# 179                    [Bislama, English]
# 180              [Italian, Latin, French]
# 181                             [Spanish]
# 182                 [Vietnamese, English]
# 183         [Hassaniya, Moroccan, Arabic]
# 184                              [Arabic]
# 185                [Bemba, Nyanja, Tonga]
# 186              [Shona, Ndebele, second]
# 187            [English, French, Punjabi]
# 188           [French, Lingala, Kingwana]
# 189           [French, Lingala, Kingwana]
# 190                              [French]
# 191                             [Spanish]
# 192                              [Korean]
# 193             [Korean, English, junior]
# 194                [Lao, French, English]
# 195                    [Palauan, English]
# 196             [Portuguese, Forro, Cabo]
#
#                                              religions
# 0                                              [Islam]
# 1          [Islam, Roman Catholic, Orthodox, Catholic]
# 2                           [Islam, Jewish, Christian]
# 3                           [Roman Catholic, Catholic]
# 4    [Roman Catholic, Protestant, Catholic, Protest...
# 5    [Roman Catholic, Protestant, Christian, Anglic...
# 6    [Roman Catholic, Jewish, Protestant, Catholic,...
# 7                                          [Christian]
# 8    [Islam, Roman Catholic, Buddhist, Christian, A...
# 9    [Islam, Roman Catholic, Protestant, Catholic, ...
# 10                                   [Islam, Orthodox]
# 11     [Roman Catholic, Christian, Anglican, Catholic]
# 12                                  [Islam, Christian]
# 13                                      [Islam, Hindu]
# 14   [Roman Catholic, Protestant, Anglican, Catholi...
# 15   [Roman Catholic, Jewish, Protestant, Orthodox,...
# 16   [Roman Catholic, Protestant, Catholic, Protest...
# 17   [Roman Catholic, Protestant, Anglican, Catholi...
# 18                                  [Islam, Christian]
# 19                                   [Buddhist, Hindu]
# 20   [Roman Catholic, Protestant, Catholic, Evangel...
# 21         [Islam, Roman Catholic, Orthodox, Catholic]
# 22                                         [Christian]
# 23   [Roman Catholic, Protestant, Catholic, Protest...
# 24                        [Islam, Buddhist, Christian]
# 25                        [Islam, Christian, Orthodox]
# 26        [Islam, Roman Catholic, Christian, Catholic]
# 27   [Islam, Roman Catholic, Protestant, Catholic, ...
# 28                                          [Buddhist]
# 29                                  [Islam, Christian]
# 30   [Roman Catholic, Protestant, Christian, Anglic...
# 31   [Islam, Roman Catholic, Protestant, Catholic, ...
# 32                                  [Islam, Christian]
# 33   [Roman Catholic, Jewish, Protestant, Catholic,...
# 34                               [Buddhist, Christian]
# 35                          [Roman Catholic, Catholic]
# 36                          [Roman Catholic, Catholic]
# 37   [Roman Catholic, Protestant, Catholic, Evangel...
# 38     [Roman Catholic, Christian, Orthodox, Catholic]
# 39                          [Roman Catholic, Catholic]
# 40                                   [Islam, Orthodox]
# 41   [Roman Catholic, Protestant, Catholic, Protest...
# 42   [Roman Catholic, Protestant, Catholic, Evangel...
# 43                                  [Islam, Christian]
# 44   [Roman Catholic, Protestant, Catholic, Protest...
# 45                          [Roman Catholic, Catholic]
# 46                          [Roman Catholic, Catholic]
# 47                                  [Islam, Christian]
# 48                  [Protestant, Catholic, Protestant]
# 49               [Roman Catholic, Christian, Catholic]
# 50   [Islam, Roman Catholic, Protestant, Christian,...
# 51   [Roman Catholic, Christian, Orthodox, Catholic...
# 52   [Roman Catholic, Jewish, Christian, Anglican, ...
# 53                                   [Islam, Orthodox]
# 54   [Islam, Roman Catholic, Christian, Hindu, Cath...
# 55                  [Christian, Orthodox, Evangelical]
# 56   [Islam, Roman Catholic, Jewish, Protestant, Ca...
# 57                                  [Islam, Christian]
# 58                                  [Islam, Christian]
# 59                         [Islam, Orthodox, Catholic]
# 60   [Islam, Roman Catholic, Protestant, Catholic, ...
# 61                                  [Islam, Christian]
# 62                                   [Islam, Orthodox]
# 63   [Roman Catholic, Protestant, Anglican, Catholi...
# 64   [Roman Catholic, Protestant, Catholic, Protest...
# 65                                  [Islam, Christian]
# 66                                  [Islam, Christian]
# 67                           [Islam, Christian, Hindu]
# 68   [Roman Catholic, Protestant, Catholic, Protest...
# 69   [Roman Catholic, Protestant, Catholic, Protest...
# 70               [Roman Catholic, Christian, Catholic]
# 71               [Roman Catholic, Christian, Catholic]
# 72                           [Islam, Christian, Hindu]
# 73   [Islam, Roman Catholic, Buddhist, Protestant, ...
# 74                          [Islam, Jewish, Christian]
# 75                                  [Islam, Christian]
# 76               [Roman Catholic, Christian, Catholic]
# 77                                  [Islam, Christian]
# 78   [Islam, Roman Catholic, Jewish, Protestant, Ca...
# 79   [Roman Catholic, Protestant, Anglican, Catholi...
# 80                               [Buddhist, Christian]
# 81                        [Islam, Christian, Orthodox]
# 82           [Islam, Protestant, Orthodox, Protestant]
# 83   [Islam, Roman Catholic, Protestant, Catholic, ...
# 84   [Roman Catholic, Protestant, Catholic, Protest...
# 85                           [Islam, Christian, Hindu]
# 86                                   [Islam, Orthodox]
# 87                [Roman Catholic, Orthodox, Catholic]
# 88   [Islam, Roman Catholic, Protestant, Christian,...
# 89                                         [Christian]
# 90                                  [Islam, Christian]
# 91                                             [Islam]
# 92   [Roman Catholic, Protestant, Catholic, Protest...
# 93   [Roman Catholic, Protestant, Christian, Orthod...
# 94   [Islam, Roman Catholic, Jewish, Protestant, Ca...
# 95                                  [Islam, Christian]
# 96                                  [Islam, Christian]
# 97                        [Buddhist, Christian, Hindu]
# 98                                             [Islam]
# 99                                  [Islam, Christian]
# 100                         [Roman Catholic, Catholic]
# 101  [Roman Catholic, Protestant, Christian, Cathol...
# 102                                            [Islam]
# 103  [Islam, Roman Catholic, Christian, Hindu, Cath...
# 104  [Roman Catholic, Protestant, Catholic, Protest...
# 105  [Roman Catholic, Protestant, Catholic, Protest...
# 106                                 [Jewish, Orthodox]
# 107                         [Roman Catholic, Catholic]
# 108                       [Islam, Buddhist, Christian]
# 109               [Roman Catholic, Orthodox, Catholic]
# 110                                 [Islam, Christian]
# 111                                 [Islam, Christian]
# 112  [Islam, Roman Catholic, Buddhist, Christian, C...
# 113                                        [Christian]
# 114  [Roman Catholic, Protestant, Christian, Cathol...
# 115                           [Islam, Buddhist, Hindu]
# 116                  [Islam, Roman Catholic, Catholic]
# 117    [Roman Catholic, Christian, Anglican, Catholic]
# 118            [Roman Catholic, Catholic, Evangelical]
# 119                                 [Islam, Christian]
# 120                                 [Islam, Christian]
# 121                                  [Islam, Orthodox]
# 122  [Roman Catholic, Christian, Catholic, Evangeli...
# 123                                     [Islam, Hindu]
# 124                          [Islam, Christian, Hindu]
# 125  [Roman Catholic, Protestant, Catholic, Protest...
# 126  [Roman Catholic, Protestant, Catholic, Protest...
# 127  [Roman Catholic, Protestant, Anglican, Catholi...
# 128  [Roman Catholic, Protestant, Catholic, Protest...
# 129              [Roman Catholic, Christian, Catholic]
# 130  [Islam, Roman Catholic, Christian, Catholic, E...
# 131  [Roman Catholic, Protestant, Orthodox, Catholi...
# 132  [Roman Catholic, Protestant, Catholic, Protest...
# 133                                            [Islam]
# 134  [Islam, Roman Catholic, Protestant, Orthodox, ...
# 135                       [Islam, Christian, Orthodox]
# 136  [Islam, Roman Catholic, Protestant, Catholic, ...
# 137  [Roman Catholic, Protestant, Anglican, Catholi...
# 138  [Roman Catholic, Christian, Anglican, Catholic...
# 139  [Roman Catholic, Protestant, Hindu, Anglican, ...
# 140              [Roman Catholic, Christian, Catholic]
# 141                         [Roman Catholic, Catholic]
# 142                                            [Islam]
# 143       [Islam, Roman Catholic, Christian, Catholic]
# 144  [Roman Catholic, Protestant, Orthodox, Catholi...
# 145  [Roman Catholic, Christian, Hindu, Anglican, C...
# 146                                 [Islam, Christian]
# 147      [Islam, Buddhist, Christian, Hindu, Catholic]
# 148  [Roman Catholic, Protestant, Catholic, Protest...
# 149             [Islam, Christian, Orthodox, Catholic]
# 150              [Roman Catholic, Christian, Catholic]
# 151                                            [Islam]
# 152             [Islam, Christian, Anglican, Catholic]
# 153                                 [Christian, Islam]
# 154                         [Roman Catholic, Catholic]
# 155                [Islam, Buddhist, Christian, Hindu]
# 156                                 [Islam, Christian]
# 157  [Islam, Roman Catholic, Protestant, Hindu, Cat...
# 158  [Roman Catholic, Jewish, Buddhist, Orthodox, C...
# 159  [Roman Catholic, Protestant, Orthodox, Catholi...
# 160                         [Islam, Jewish, Christian]
# 161                              [Buddhist, Christian]
# 162                                            [Islam]
# 163                                 [Islam, Christian]
# 164                       [Islam, Buddhist, Christian]
# 165                                 [Islam, Christian]
# 166                                        [Christian]
# 167  [Islam, Roman Catholic, Christian, Hindu, Angl...
# 168                         [Islam, Jewish, Christian]
# 169                                 [Islam, Christian]
# 170                                  [Islam, Orthodox]
# 171                                 [Church of Tuvalu]
# 172  [Islam, Roman Catholic, Protestant, Catholic, ...
# 173  [Jewish, Protestant, Orthodox, Catholic, Prote...
# 174                          [Islam, Christian, Hindu]
# 175  [Roman Catholic, Christian, Hindu, Anglican, C...
# 176  [Roman Catholic, Jewish, Protestant, Catholic,...
# 177  [Roman Catholic, Jewish, Protestant, Catholic,...
# 178                                  [Islam, Orthodox]
# 179    [Roman Catholic, Christian, Anglican, Catholic]
# 180                         [Roman Catholic, Catholic]
# 181  [Roman Catholic, Protestant, Catholic, Protest...
# 182  [Islam, Buddhist, Protestant, Catholic, Protes...
# 183                                            [Islam]
# 184                  [Islam, Jewish, Christian, Hindu]
# 185                          [Islam, Christian, Hindu]
# 186                                        [Christian]
# 187  [Roman Catholic, Protestant, Catholic, Protest...
# 188  [Islam, Roman Catholic, Protestant, Catholic, ...
# 189                                 [Islam, Christian]
# 190                                 [Islam, Christian]
# 191  [Islam, Roman Catholic, Buddhist, Protestant, ...
# 192                                         [Buddhism]
# 193                              [Buddhist, Christian]
# 194                              [Buddhist, Christian]
# 195                         [Islam, Jewish, Christian]
# 196                            [Catholic, Evangelical]
