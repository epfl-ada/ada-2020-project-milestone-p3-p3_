# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
import pycountry

# %% [markdown]
# # Acquiring Most Common Languages per Country

# %%
# url of a website containg most common languages per country
language_url = "https://www.infoplease.com/world/countries/languages-spoken-in-each-country-of-the-world"

# %%
# get html page
page = requests.get(language_url)

# transform to soup object
soup = BeautifulSoup(page.content, 'html.parser')
    
# find the table with all information (right, top of wikipedia article)
table = soup.find('table')

# get all the rows of the table, discard the header line
rows = table.find_all("tr")[1:]

# %%
country_languages = {}

# regular expressions
find_country_regex = r">.*<"
remove_bracket_regex = r'\([^\]]*\)'

# extract countries and corresponding languages
for row in rows:
    # get the country names
    country = str(re.findall(find_country_regex, str(row.findChild("a")))[0][1:-1])
    # remove hexadecimals
    country = country.encode('ascii', errors='ignore').decode("UTF-8")
    # remove brackets
    country = re.sub(remove_bracket_regex, "", country)
    # replace st. by sant
    country = country.replace("St.", "Saint")
    #country = country.decode('utf8').encode('ascii', errors='ignore')
    # contains the whole row of one country
    temp_list = str(row.findAll('p')[1])[3:-4].split(",")
    # extract only the language names
    languages = []
    for language in temp_list:
        # only get 3 languages
        if len(languages) < 3:
            languages.append(re.findall(r"([^\s]+)", language)[0])
    # add to dictionary
    country_languages[country] = languages

# %%
# fix wrong words
remove_words = ["other", "and", "widely", "tribal", "24", "60", "declining", "Qazaq)", 
                "multilingual", "indigenous", "which", "small", "unspecified", "but", "universal",
               "regular", "120", "the", "only", "one", "taught", "used", "local", "some", "numerous", 
                "a", "Standard", "based"]

for country, language in country_languages.items():
    for illegal_word in remove_words:
        if illegal_word in country_languages[country]:
            country_languages[country].remove(illegal_word)
################################################################################################
# fix country names for pycountry
replace_country_names_dic = {"Congo, Democratic Republic of the":"Congo, The Democratic Republic of the",     
                        "Congo, Republic of": "Congo",
                        "Cape Verde":"Cabo Verde",
                        "Palestinian State ":"Palestine, State of",
                        "East Timor":"Timor-Leste",
                        "Korea, North":"Korea, Democratic People's Republic of",
                        "Korea, South":"Korea, Republic of",
                        "Laos":"Lao People's Democratic Republic",
                        "So Tom and Prncipe":"Sao Tome and Principe",
                        "Cte d'Ivoire":"Côte d'Ivoire"}
# since we cannot change the size of the dictionary withing a loop, save the ones that are supposed
# to be deleted and their replacements
to_delete = []
to_add = {}
# depending on replace_country_names_dic, look at what to replace and what to replace with
for country, language_list in country_languages.items():
    if country in replace_country_names_dic.keys():
        to_add[replace_country_names_dic[country]] = language_list
        to_delete.append(country)
        
# delete old names
for country in to_delete:
    del country_languages[country]
    
# add new ones
country_languages = {**country_languages, **to_add}

################################################################################################
# manual fixes
country_languages["China"].extend(["Mandarin", "Chinese"])
country_languages["Western Sahara"].extend(["Arabic"])
country_languages["Philippines"].extend(["English"])
del country_languages["Kosovo"] # not included in pycountry

# %%
country_languages
# Out:
# {'Afghanistan': ['Afghan', 'Pashto', 'Uzbek'],
#  'Albania': ['Albanian', 'Greek'],
#  'Algeria': ['Arabic', 'French', 'Berber'],
#  'Andorra': ['Catalan', 'French', 'Castilian'],
#  'Angola': ['Portuguese', 'Umbundu', 'Kikongo'],
#  'Antigua and Barbuda': ['English', 'Antiguan'],
#  'Argentina': ['Spanish', 'Italian', 'English'],
#  'Armenia': ['Armenian', 'Kurdish'],
#  'Australia': ['English', 'Mandarin', 'Arabic'],
#  'Austria': ['German', 'Turkish', 'Serbian'],
#  'Azerbaijan': ['Azerbaijani', 'Russian', 'Armenian'],
#  'Bahamas': ['Azerbaijani', 'Russian', 'Armenian'],
#  'Bahrain': ['Arabic', 'English', 'Farsi'],
#  'Bangladesh': ['Bangla', 'also'],
#  'Barbados': ['English', 'Bajan'],
#  'Belarus': ['Russian', 'Belarusian'],
#  'Belgium': ['Dutch', 'French', 'German'],
#  'Belize': ['English', 'Spanish', 'Creole'],
#  'Benin': ['French', 'Fon'],
#  'Bhutan': ['Sharchhopka', 'Dzongkha', 'Lhotshamkha'],
#  'Bolivia': ['Spanish', 'Quechua', 'Aymara'],
#  'Bosnia and Herzegovina': ['Bosnian', 'Serbian', 'Croatian'],
#  'Botswana': ['Setswana', 'Sekalanga', 'Shekgalagadi'],
#  'Brazil': ['Portuguese'],
#  'Brunei': ['Malay', 'English', 'Chinese'],
#  'Bulgaria': ['Bulgarian', 'Turkish', 'Romani'],
#  'Burkina Faso': ['French', 'native'],
#  'Burundi': ['Kirundi', 'French'],
#  'Cambodia': ['Khmer'],
#  'Cameroon': ['English', 'French'],
#  'Canada': ['English', 'French', 'Punjabi'],
#  'Central African Republic': ['French', 'Sangho'],
#  'Chad': ['French', 'Arabic', 'Sara'],
#  'Chile': ['Spanish', 'English'],
#  'China': ['Yue', 'Mandarin', 'Chinese'],
#  'Colombia': ['Spanish'],
#  'Comoros': ['Arabic', 'French', 'Shikomoro'],
#  'Costa Rica': ['Spanish', 'English'],
#  'Croatia': ['Croatian', 'Serbian'],
#  'Cuba': ['Spanish'],
#  'Cyprus': ['Greek', 'Turkish', 'English'],
#  'Czech Republic': ['Greek', 'Turkish', 'English'],
#  'Denmark': ['Danish', 'Faroese', 'Greenlandic'],
#  'Djibouti': ['French', 'Arabic', 'Somali'],
#  'Dominica': ['English', 'French'],
#  'Dominican Republic': ['Spanish'],
#  'Ecuador': ['Spanish', 'Quechua'],
#  'Egypt': ['Arabic', 'Arabic', 'English'],
#  'El Salvador': ['Spanish', 'Nawat'],
#  'Equatorial Guinea': ['Spanish', 'Bubi'],
#  'Eritrea': ['Tigrinya', 'Arabic', 'English'],
#  'Estonia': ['Estonian', 'Russian', 'Ukrainian'],
#  'Eswatini': ['English', 'siSwati'],
#  'Ethiopia': ['Oromo', 'Amharic', 'Somali'],
#  'Fiji': ['English', 'Fijian', 'Hindustani'],
#  'Finland': ['Finnish', 'Swedish', 'Russian'],
#  'France': ['French', 'Breton'],
#  'Gabon': ['French', 'Fang', 'Myene'],
#  'Gambia': ['French', 'Fang', 'Myene'],
#  'Georgia': ['Georgian', 'Azeri', 'Armenian'],
#  'Germany': ['German'],
#  'Ghana': ['Asante', 'Ewe', 'Fante'],
#  'Greece': ['Greek'],
#  'Grenada': ['English', 'French'],
#  'Guatemala': ['Spanish', 'Maya', "K'iche"],
#  'Guinea': ['French', 'Pular', 'Maninka'],
#  'Guinea-Bissau': ['Crioulo', 'Portuguese', 'Pular'],
#  'Guyana': ['English', 'Guyanese', 'Amerindian'],
#  'Haiti': ['French', 'Creole'],
#  'Honduras': ['Spanish', 'Amerindian'],
#  'Hungary': ['Hungarian', 'English', 'German'],
#  'Iceland': ['Icelandic', 'English', 'Nordic'],
#  'India': ['Hindi', 'Bengali', 'Marathi'],
#  'Indonesia': ['Bahasa', 'modified', 'English'],
#  'Iran': ['Persian', 'Azeri', 'Kurdish'],
#  'Iraq': ['Arabic', 'Kurdish', 'Turkmen'],
#  'Ireland': ['English', 'Irish'],
#  'Israel': ['Hebrew', 'Arabic', 'English'],
#  'Italy': ['Italian', 'German', 'French'],
#  'Jamaica': ['English', 'English'],
#  'Japan': ['Japanese'],
#  'Jordan': ['Arabic', 'English'],
#  'Kazakhstan': ['Kazakh', 'Russian'],
#  'Kenya': ['English', 'Kiswahili'],
#  'Kiribati': ['I-Kiribati', 'English'],
#  'Kuwait': ['Arabic', 'English'],
#  'Kyrgyzstan': ['Kyrgyz', 'Uzbek', 'Russian'],
#  'Latvia': ['Latvian', 'Russian'],
#  'Lebanon': ['Arabic', 'French', 'English'],
#  'Lesotho': ['Sesotho', 'English', 'Zulu'],
#  'Liberia': ['English'],
#  'Libya': ['Arabic', 'Italian', 'English'],
#  'Liechtenstein': ['German', 'Italian', 'Turkish'],
#  'Lithuania': ['Lithuanian', 'Russian', 'Polish'],
#  'Luxembourg': ['Luxembourgish', 'Portuguese', 'French'],
#  'Madagascar': ['French', 'Malagasy', 'English'],
#  'Malawi': ['English', 'Chewa', 'Lambya'],
#  'Malaysia': ['Bahasa', 'English', 'Chinese'],
#  'Maldives': ['Dhivehi', 'dialect', 'script'],
#  'Mali': ['French', 'Bambara', 'Peuhl/Foulfoulbe'],
#  'Malta': ['Maltese', 'English'],
#  'Marshall Islands': ['Marshallese'],
#  'Mauritania': ['Arabic', 'Pular', 'Soninke'],
#  'Mauritius': ['Creole', 'Bhojpuri', 'French'],
#  'Mexico': ['Spanish', 'Spanish'],
#  'Micronesia': ['Spanish', 'Spanish'],
#  'Moldova': ['Moldovan/Romanian', 'Russian'],
#  'Monaco': ['French', 'English', 'Italian'],
#  'Mongolia': ['Mongolian', 'Turkic', 'Russian'],
#  'Montenegro': ['Serbian', 'Montenegrin', 'Bosnian'],
#  'Morocco': ['Arabic', 'Berber', 'Tachelhit'],
#  'Mozambique': ['Makhuwa', 'Portuguese', 'Tsonga'],
#  'Myanmar': ['Makhuwa', 'Portuguese', 'Tsonga'],
#  'Namibia': ['Oshiwambo', 'Nama/Damara', 'Kavango'],
#  'Nauru': ['Nauruan', 'English'],
#  'Nepal': ['Nepali', 'Maithali', 'Bhojpuri'],
#  'Netherlands': ['Dutch'],
#  'New Zealand': ['English', 'Maori', 'Samoan'],
#  'Nicaragua': ['Spanish', 'Miskito', 'Mestizo'],
#  'Niger': ['French', 'Hausa', 'Djerma'],
#  'Nigeria': ['English', 'Hausa', 'Yoruba'],
#  'North Macedonia': ['Macedonian', 'Albanian', 'Turkish'],
#  'Norway': ['Bokmal', 'Nynorsk'],
#  'Oman': ['Arabic', 'English', 'Baluchi'],
#  'Pakistan': ['Punjabi', 'Sindhi', 'Saraiki'],
#  'Palau': ['Palauan', 'English'],
#  'Panama': ['Spanish', 'Buglere'],
#  'Papua New Guinea': ['Tok', 'English', 'Hiri'],
#  'Paraguay': ['Spanish', 'only'],
#  'Peru': ['Spanish', 'Quechua', 'Aymara'],
#  'Philippines': ['Cebuano', 'Ilocano', 'English'],
#  'Poland': ['Polish', 'Silesian'],
#  'Portugal': ['Portuguese', 'Mirandese'],
#  'Qatar': ['Arabic', 'English'],
#  'Romania': ['Romanian', 'Hungarian', 'Romani'],
#  'Russia': ['Russian', 'Tatar', 'Chechen'],
#  'Rwanda': ['Kinyarwanda', 'French'],
#  'Saint Kitts and Nevis': ['Sinhala', 'Tamil', 'English'],
#  'Saint Lucia': ['Sinhala', 'Tamil', 'English'],
#  'Saint Vincent and the Grenadines': ['Sinhala', 'Tamil', 'English'],
#  'Samoa': ['Samoan', 'Somoan/English', 'English'],
#  'San Marino': ['Italian'],
#  'Saudi Arabia': ['Arabic'],
#  'Senegal': ['French', 'Wolof', 'Pular'],
#  'Serbia': ['Serbian', 'Hungarian', 'Bosnian'],
#  'Seychelles': ['Seychellois', 'English', 'French'],
#  'Sierra Leone': ['English', 'Mende'],
#  'Singapore': ['English', 'Mandarin'],
#  'Slovakia': ['Slovak', 'Hungarian', 'Roma'],
#  'Slovenia': ['Slovene', 'Serbo-Croatian'],
#  'Solomon Islands': ['Melanesian', 'English'],
#  'Somalia': ['Somali', 'according', 'Arabic'],
#  'South Africa': ['isiZulu', 'isiXhosa', 'Afrikaans'],
#  'South Sudan': ['English', 'Arabic', 'regional'],
#  'Spain': ['Castilian', 'Catalan'],
#  'Sri Lanka': ['Sinhala', 'Tamil', 'English'],
#  'Sudan': ['Arabic', 'English', 'Nubian'],
#  'Suriname': ['Dutch', 'English', 'Sranang'],
#  'Sweden': ['Swedish'],
#  'Switzerland': ['German', 'French', 'Italian'],
#  'Syria': ['Arabic', 'Kurdish', 'Armenian'],
#  'Taiwan': ['Mandarin', 'Taiwanese', 'Hakka'],
#  'Tajikistan': ['Tajik', 'Uzbek', 'Kyrgyz'],
#  'Tanzania': ['Kiswahili', 'Kiunguja', 'English'],
#  'Thailand': ['Thai', 'Thai'],
#  'Togo': ['French', 'Ewe'],
#  'Tonga': ['Tongan', 'Tongan', 'English'],
#  'Trinidad and Tobago': ['English', 'Trinidadian', 'Tobagonian'],
#  'Tunisia': ['Arabic', 'French'],
#  'Turkey': ['Turkish', 'Kurdish'],
#  'Turkmenistan': ['Turkmen', 'Russian', 'Uzbek'],
#  'Tuvalu': ['Tuvaluan', 'English', 'Samoan'],
#  'Uganda': ['English'],
#  'Ukraine': ['Ukrainian', 'Russian'],
#  'United Arab Emirates': ['Arabic', 'English', 'Hindi'],
#  'United Kingdom': ['English'],
#  'United States': ['English', 'Spanish', 'Chinese'],
#  'Uruguay': ['Spanish'],
#  'Uzbekistan': ['Uzbek', 'Russian', 'Tajik'],
#  'Vanuatu': ['Bislama', 'English'],
#  'Vatican City': ['Italian', 'Latin', 'French'],
#  'Venezuela': ['Spanish'],
#  'Vietnam': ['Vietnamese', 'English'],
#  'Western Sahara': ['Hassaniya', 'Moroccan', 'Arabic'],
#  'Yemen': ['Arabic'],
#  'Zambia': ['Bemba', 'Nyanja', 'Tonga'],
#  'Zimbabwe': ['Shona', 'Ndebele', 'second'],
#  'Cabo Verde': ['English', 'French', 'Punjabi'],
#  'Congo, The Democratic Republic of the': ['French', 'Lingala', 'Kingwana'],
#  'Congo': ['French', 'Lingala', 'Kingwana'],
#  "Côte d'Ivoire": ['French'],
#  'Timor-Leste': ['Spanish'],
#  "Korea, Democratic People's Republic of": ['Korean'],
#  'Korea, Republic of': ['Korean', 'English', 'junior'],
#  "Lao People's Democratic Republic": ['Lao', 'French', 'English'],
#  'Palestine, State of': ['Palauan', 'English'],
#  'Sao Tome and Principe': ['Portuguese', 'Forro', 'Cabo']}

# %% [markdown]
# # Acquiring Most Common Religions per Country

# %%
# url of a website containg most common languages per country
language_url = "https://www.infoplease.com/world/social-statistics/world-religions"
religions_permitted = ["Islam", "Roman Catholic", "Jewish", "Buddhist", "Protestant", "Christian", 
                       "Orthodox", "Buddhism", "Hindu", "Anglican", "Catholic", "Evangelical",
                      "Church of Tuvalu"]

# %%
# get html page
page = requests.get(language_url)

# transform to soup object
soup = BeautifulSoup(page.content, 'html.parser')
    
# find the table with all information (right, top of wikipedia article)
table = soup.find('table')

# get all the rows of the table, discard the header line
rows = table.find_all("tr")

# %%
country_religions = {}

# regular expressions
find_country_regex = r">.*<"
find_country_regex_alt = r"<td>(.*?)</td>"
remove_bracket_regex = r"\([^\]]*\)"
get_percentage_regex = r"/d{,3}\%"
get_first_country_regex = r"(.+?)\d" 
# extract countries and corresponding languages
for row in rows:
    # get the country names depending how the text is embedded in the html
    if row.findChild("a"):

        country = str(re.findall(find_country_regex, str(row.findChild("a")))[0][1:-1])
    else:
        country = str(re.findall(find_country_regex_alt, str(row))[0])
    
    # remove hexadecimals
    country = country.encode('ascii', errors='ignore').decode("UTF-8")
    # remove brackets
    country = re.sub(remove_bracket_regex, "", country)
    # replace st. by sant
    country = country.replace("St.", "Saint")
    # removing trailing whitespace
    country = country.rstrip()
    
    # fill dictionary
    country_religions[country] = []
    print("="*10)
    # HORRIFICX 
    # string of all languages with percentages
    languages_text = str(str(re.findall(find_country_regex_alt, str(row))[1]))
    print(languages_text)
    if not re.findall(get_first_country_regex, languages_text):
        first_language = languages_text
        found_one = False
        for r in religions_permitted:
                        if found_one:
                            break
                        if r in str(first_language):
                            found_one = True
                            # merge branches of one religion
                            if r in ["Roman Catholic", "Protestant", "Christian", "Orthodox", "Anglican", "Catholic", "Evangelical", "Church of Tuvalu"]:
                                r = "Christianity"
                            elif r == "Buddhist":
                                r = "Buddhism"
                            elif r == "Hindu":
                                r = "Hinduism"

                            if not r in country_religions[country]:
                                country_religions[country] = r
                                print(r)
        
        
    else:
                
        found_one = False
        languages = re.findall(get_first_country_regex, languages_text)
        
        for first_language in languages:
            # remove possible brackets
            if "(" in first_language:
                brckt_indx = first_language.find("(")
                first_language = first_language[:brckt_indx]

    
            for r in religions_permitted:
                if found_one:
                    break
                if r in str(first_language):
                    found_one = True
                    # merge branches of one religion
                    if r in ["Roman Catholic", "Protestant", "Christian", "Orthodox", "Anglican", "Catholic", "Evangelical", "Church of Tuvalu"]:
                        r = "Christianity"
                    elif r == "Buddhist":
                        r = "Buddhism"
                    elif r == "Hindu":
                        r = "Hinduism"

                    if not r in country_religions[country]:
                        country_religions[country] = r
                        print(r)
            if found_one:
                break
# Out:
# ==========
# Islam (Sunni 80%, Shiite 19%), other 1%
# Islam
# ==========
# Islam 70%, Albanian Orthodox 20%, Roman Catholic 10% (est.)
# Islam
# ==========
# Islam (Sunni) 99% (state religion), Christian and Jewish 1%
# Islam
# ==========
# Roman Catholic (predominant)
# Christianity
# ==========
# Indigenous 47%, Roman Catholic 38%, Protestant 15% (1998 est.)
# Christianity
# ==========
# Christian (predominantly Anglican and other Protestant; some Roman Catholic)
# Christianity
# ==========
# Roman Catholic 92%, Protestant 2%, Jewish 2%, other 4%
# Christianity
# ==========
# Armenian Apostolic 95%, other Christian 4%, Yezidi 1%
# Christianity
# ==========
# Roman Catholic 26%, Anglican 21%, other Christian 21%, Buddhist 2%, Islam 2%, other 1%, none 15% (2001)
# Christianity
# ==========
# Roman Catholic 74%, Protestant 5%, Islam 4%, none 12% (2001)
# Christianity
# ==========
# Islam 93%, Russian Orthodox 3%, Armenian Orthodox 2%, other 2% (1995 est.)
# Islam
# ==========
# Baptist 35%, Anglican 15%, Roman Catholic 14%, Pentecostal 8%, Church of God 5%, Methodist 4%, other Christian 15% (2000)
# Christianity
# ==========
# Islam (Shiite and Sunni) 81%, Christian 9%
# Islam
# ==========
# Islam 83%, Hindu 16%, other 1% (1998)
# Islam
# ==========
# Protestant 67% (Anglican 40%, Pentecostal 8%, Methodist 7%, other 12%), Roman Catholic 4%, none 17%, other 12%
# Christianity
# ==========
# Eastern Orthodox 80%, other (including Roman Catholic, Protestant, Jewish, and Muslim) 20% (1997 est.)
# Christianity
# ==========
# Roman Catholic 75%, Protestant or other 25%
# Christianity
# ==========
# Roman Catholic 50%, Protestant 27% (Pentecostal 7%, Anglican 5%, Seventh-Day Adventist 5%, Mennonite 4%, Methodist 4%, Jehovah's Witnesses 2%), none 9%, other 14% (2000)
# Christianity
# ==========
# indigenous 50%, Christian 30%, Islam 20%
# Christianity
# ==========
# Lamaistic Buddhist 75%, Indian- and Nepalese-influenced Hinduism 25%
# Buddhism
# ==========
# Roman Catholic 95%, Protestant (Evangelical Methodist) 5%
# Christianity
# ==========
# Islam 40%, Orthodox 31%, Roman Catholic 15%, other 14%
# Islam
# ==========
# Christian 72%, Badimo 6%, none 21% (2001)
# Christianity
# ==========
# Roman Catholic 74%, Protestant 15%, Spiritualist 1%, none 7% (2000)
# Christianity
# ==========
# Islam (official religion) 67%, Buddhist 13%, Christian 10%, indigenous beliefs and other 10%
# Islam
# ==========
# Bulgarian Orthodox 83%, Islam 12%, other Christian 1% (2001)
# Christianity
# ==========
# Islam 50%, indigenous beliefs 40%, Christian (mainly Roman Catholic) 10%
# Islam
# ==========
# Roman Catholic 62%, indigenous 23%, Islam 10%, Protestant 5%
# Christianity
# ==========
# Theravada Buddhist 95%, others 5%
# Buddhism
# ==========
# indigenous beliefs 40%, Christian 40%, Islam 20%
# Christianity
# ==========
# Roman Catholic 43%, Protestant 23% (including United Church 10%, Anglican 7%, Baptist 2%, Lutheran 2%), other Christian 4%, Muslim 2%, none 16% (2001)
# Christianity
# ==========
# Roman Catholic (infused with indigenous beliefs), Protestant (mostly Church of the Nazarene)
# Christianity
# ==========
# indigenous beliefs 35%, Protestant and Roman Catholic (both with animist influence) 25% each, Islam 15%
# Christianity
# ==========
# Islam 51%, Christian 35%, animist 7%, other 7%
# Islam
# ==========
# Roman Catholic 89%, Protestant 11%, small Jewish population
# Christianity
# ==========
# Officially atheist; Daoist (Taoist), Buddhist, Christian 3%–4%, Muslim 1%–2% (2002 est.)
# ==========
# Roman Catholic 90%
# Christianity
# ==========
# Sunni Muslim 98%, Roman Catholic 2%
# Christianity
# ==========
# Roman Catholic 50%, Protestant 20%, Kimbanguist 10%, Islam 10%; other syncretic and indigenous 10%
# Christianity
# ==========
# Christian 50%, animist 48%, Islam 2%
# Christianity
# ==========
# Roman Catholic 76%, Evangelical 14%, Jehovah's Witnesses 1%, other Protestant 1%, other 5%, none 3%
# Christianity
# ==========
# indigenous 25%–40%, Islam 35%–40%, Christian 20%–30% (2001)
# Islam
# ==========
# Roman Catholic 88%, Orthodox 4%, Muslim 1%, other Christian less than 1%, none 5% (2001)
# Christianity
# ==========
# predominantly Roman Catholic and Santería (Afro-Cuban syncretic religion)
# Christianity
# ==========
# Greek Orthodox 78%, Islam 18%, Maronite, Armenian Apostolic, and other 4%
# Christianity
# ==========
# Roman Catholic 27%, Protestant 2%, unaffiliated 59% (2001)
# Christianity
# ==========
# Evangelical Lutheran 95%, other Protestant and Roman Catholic 3%, Muslim 2%
# Christianity
# ==========
# Islam 94%, Christian 6%
# Islam
# ==========
# Roman Catholic 77%, Protestant 15% (Methodist 5%, Pentecostal 3%, Seventh-Day Adventist 3%, Baptist 2%, other 2%), none 2%
# Christianity
# ==========
# Roman Catholic 95%
# Christianity
# ==========
# Roman Catholic 90%, Islam 4%, Protestant 3%, Hindu 0.5%, Buddhist, animist (1992 est.)
# Christianity
# ==========
# Roman Catholic 95%
# Christianity
# ==========
# Islam (mostly Sunni) 90%, Coptic 9%, Christian 1%, other 6%
# Islam
# ==========
# Catholics 83%; growing population of evangelical Protestants (1992)
# Christianity
# ==========
# nominally Christian and predominantly Roman Catholic, pagan practices
# Christianity
# ==========
# Islam, Eritrean Orthodox Christianity, Roman Catholic, Protestant
# Islam
# ==========
# Evangelical Lutheran 14%, Russian Orthodox 13%, other Christian (including Methodist, Seventh-Day Adventist, Roman Catholic, Pentecostal) 1%, unaffiliated 34%, none 6% (2001)
# Christianity
# ==========
# Islam 45%–50%, Ethiopian Orthodox 35%–40%, animist 12%, other 3%–8%
# Islam
# ==========
# Christian 52% (Methodist 37%, Roman Catholic 9%), Hindu 38%, Islam 8%, other 2%
# Christianity
# ==========
# Evangelical Lutheran 84%, Greek Orthodox 1%, other Christian 1%, none 14%
# Christianity
# ==========
# Roman Catholic 83%–88%, Protestant 2%, Islam 5%–10%, Jewish 1%, unaffiliated 4%
# Christianity
# ==========
# Christian 55%–75%, animist, Islam less than 1%
# Christianity
# ==========
# Islam 90%, Christian 9%, indigenous 1%
# Islam
# ==========
# Orthodox 84%, Islam 10%, Armenian-Gregorian 4%, Catholic 1% (2002)
# Christianity
# ==========
# Protestant 34%, Roman Catholic 34%, Islam 4%, Unaffiliated or other 28%
# Christianity
# ==========
# Christian 63%, indigenous beliefs 21%, Islam 16%
# Christianity
# ==========
# Greek Orthodox 98%, Islam 1%, other 1%
# Christianity
# ==========
# Roman Catholic 53%, Anglican 14%, other Protestant 33%
# Christianity
# ==========
# Roman Catholic, Protestant, indigenous Mayan beliefs
# Christianity
# ==========
# Islam 85%, Christian 8%, indigenous 7%
# Islam
# ==========
# indigenous beliefs 50%, Islam 45%, Christian 5%
# Islam
# ==========
# Christian 50%, Hindu 35%, Islam 10%, other 5%
# Christianity
# ==========
# Roman Catholic 80%, Protestant 16% (Baptist 10%, Pentecostal 4%, Adventist 1%, other 1%), other 3%, none 1%. Note: roughly half the population practices Vaudou
# Christianity
# ==========
# Roman Catholic 97%, Protestant 3%
# Christianity
# ==========
# Roman Catholic 52%, Calvinist 16%, Lutheran 3%, Greek Catholic 3%, other Christian 1%, unaffiliated 15% (2001)
# Christianity
# ==========
# Lutheran Church of Iceland 85.5%, Reykjavik Free Church 2.1%, Roman Catholic Church 2%, Hafnarfjorour Free Church 1.5%, other Christian 2.7%, other or unspecified 3.8%, unaffiliated 2.4% (2004)
# Christianity
# ==========
# Hindu 81%, Islam 13%, Christian 2%, Sikh 2% (2001)
# Hinduism
# ==========
# Islam 88%, Protestant 5%, Roman Catholic 3%, Hindu 2%, Buddhist 1% (1998)
# Islam
# ==========
# Islam 98% (Shi'a 89%, Sunni 9%); Zoroastrian, Jewish, Christian, and Baha'i 2%
# Islam
# ==========
# Islam 97% (Shiite 60%–65%, Sunni 32%–37%), Christian or other 3%
# Islam
# ==========
# Roman Catholic 88%, Church of Ireland 3%, other Christian 2%, none 4%
# Christianity
# ==========
# Judaism 77%, Islam 16%, Christian 2%, Druze 2% (2003)
# Islam
# ==========
# Roman Catholic approx. 90%, Protestant, Jewish, Islamic
# Christianity
# ==========
# Protestant 61.3%, (Church of God 21.2%, Baptist 8.8%, Anglican 5.5%, Seventh-Day Adventist 9%, Pentecostal 7.6%, Methodist 2.7%, United Church 2.7%, Brethren 1.1%, Jehovah's Witness 1.6%, Moravian 1.1%), Roman Catholic 4%, other including some spiritual cults 34.7%
# Christianity
# ==========
# Shintoist and Buddhist 84%, other 16% (including Christian 0.7%)
# Buddhism
# ==========
# Islam (Sunni) 92%, Christian 6% (mostly Greek Orthodox), other 2%
# Islam
# ==========
# Islam 47%, Russian Orthodox 44%, Protestant 2%, other 7%
# Islam
# ==========
# Protestant 45%, Roman Catholic 33%, indigenous beliefs 10%, Islam 10%, others 2% (note: estimates vary widely)
# Christianity
# ==========
# Roman Catholic 52%, Protestant (Congregational) 40%, some Seventh-Day Adventist, Muslim, Baha'i, Latter-day Saints, and Church of God (1999)
# Christianity
# ==========
# Buddhism and Confucianism; religious activities almost nonexistent
# Buddhism
# ==========
# no affiliation 46%, Christian 26%, Buddhist 26%, Confucianist 1%, other 1%
# Christianity
# ==========
# Islam 85% (Sunni 70%, Shiite 30%); Christian, Hindu, Parsi, and other 15%
# Islam
# ==========
# Islam 75%; Russian Orthodox 20%; other 5%
# Islam
# ==========
# Buddhist 60%, animist and other 40% (including Christian 2%)
# Buddhism
# ==========
# Lutheran, Roman Catholic, Russian Orthodox
# Christianity
# ==========
# Islam 60% (Shi'a, Sunni, Druze, Isma'ilite, Alawite/Nusayri), Christian 39% (Maronite, Melkite, Syrian, Armenian, and Roman Catholic; Greek, Armenian, and Syrian Orthodox; Chaldean; Assyrian; Copt; Protestant), other 1%
# Islam
# ==========
# Christian 80%, indigenous beliefs 20%
# Christianity
# ==========
# traditional 40%, Christian 40%, Islam 20%
# Christianity
# ==========
# Islam (Sunni) 97%
# Islam
# ==========
# Roman Catholic, 77%, Protestant, 7%; unknown, 11% (2002)
# Christianity
# ==========
# Roman Catholic 79%, Russian Orthodox 4%, Protestant (including Lutheran, evangelical Christian Baptist) 2%, none 10% (2001)
# Christianity
# ==========
# Roman Catholic 87%; Protestant, Jewish, Islamic 13% (2000)
# Christianity
# ==========
# Macedonian Orthodox 32%, Islam 17% (2002)
# Christianity
# ==========
# indigenous beliefs 52%, Christian 41%, Islam 7%
# Christianity
# ==========
# Christian 80%, Islam 13%, none 4% (1998)
# Christianity
# ==========
# Muslim, Buddhist, Daoist, Hindu, Christian, Sikh; Shamanism (East Malaysia)
# Buddhism
# ==========
# Islam (Sunni)
# Islam
# ==========
# Islam 90%, indigenous beliefs 9%, Christian 1%
# Islam
# ==========
# Roman Catholic 98%
# Christianity
# ==========
# Protestant 55%, Assembly of God 26%, Roman Catholic 8%, Bukot nan Jesus 3%, Mormon 2%, other Christian 4%, none 2% (1999)
# Christianity
# ==========
# Islam 100%
# Islam
# ==========
# Hindu 48%, Roman Catholic 24%, other Christian 8%, Islam 17% (2000)
# Hinduism
# ==========
# nominally Roman Catholic 89%, Protestant 6%, other 5%
# Christianity
# ==========
# Roman Catholic 50%, Protestant 47%
# Christianity
# ==========
# Eastern Orthodox 98%, Jewish 1.5%, Baptist and other 0.5% (2000)
# Christianity
# ==========
# Roman Catholic 90%
# Christianity
# ==========
# Buddhist Lamaist 50%, Islam 4%, Shamanism and Christian 4%, none 40% (2004)
# Buddhism
# ==========
# Orthodox, Muslim, Roman Catholic
# Christianity
# ==========
# Islam 99%, Christian 1%
# Islam
# ==========
# Mozambique 24%, Islam 18%, Zionist Christian 18%, none 23% (1997)
# Islam
# ==========
# Buddhist 89%, Christian 4% (Baptist 3%, Roman Catholic 1%), Islam 4%, Animist 1%, other 2%
# Buddhism
# ==========
# Christian 80%–90% (Lutheran at least 50%), indigenous beliefs 10%–20%
# Christianity
# ==========
# Christian (two-thirds Protestant, one-third Roman Catholic)
# Christianity
# ==========
# Hindu 81%, Buddhist 11%, Islam 4%, Kirant 4% (2001)
# Hinduism
# ==========
# Roman Catholic 31%, Dutch Reformed 13%, Calvinist 7%, Islam 6%, none 41% (2002)
# Christianity
# ==========
# Anglican 15%, Roman Catholic 12%, Presbyterian 11%, Methodist 3%, Pentecostal 2%, Baptist 1%, other Christian 9%, none 26% (2001)
# Christianity
# ==========
# Roman Catholic 73%, Evangelical 15%, Moravian 2%, none 9% (1995)
# Christianity
# ==========
# Islam 80%, indigenous beliefs and Christian 20%
# Islam
# ==========
# Islam 50%, Christian 40%, indigenous beliefs 10%
# Islam
# ==========
# Evangelical Lutheran 86% (state church), Pentecostal 1%, Roman Catholic 1%, other Christian 2% (2004)
# Christianity
# ==========
# Islam: Ibadhi 75%, Sunni, Shi'a; Hindu
# Islam
# ==========
# Islam 97% (Sunni 77%, Shiite 20%); Christian, Hindu, and other 3%
# Islam
# ==========
# Roman Catholic 42%, Protestant 23%, Modekngei 9% (indigenous), Seventh-Day Adventist 5%, Jehovah's Witness 1%, Latter-Day Saints 1%, other religion 3%, unspecified or none 16% (2000)
# Christianity
# ==========
# West Bank: Islam 75% (predominantly Sunni), Jewish 17%, Christian and other 8%; Gaza Strip: Islam 98.7% (predominantly Sunni), Christian 0.7%, Jewish 0.6%.
# Islam
# ==========
# Roman Catholic 85%, Protestant 15%
# Christianity
# ==========
# Roman Catholic 22%, Lutheran 16%, Presbyterian/Methodist/London Missionary Society 8%, Anglican 5%, Evangelical Alliance 4%, Seventh-Day Adventist 1%, other Protestant 10%, indigenous beliefs 34%
# Christianity
# ==========
# Roman Catholic 90%, Mennonite, other Protestant 10%
# Christianity
# ==========
# Roman Catholic 81%, Seventh-Day Adventist 1%, other Christian 1%, unspecified or none 16% (2003 est.)
# Christianity
# ==========
# Roman Catholic 81%, Evangelical 3%, Iglesia ni Kristo 2%, Aglipayan 2%, other Christian 5%, Islam 5% (2000)
# Christianity
# ==========
# Roman Catholic 90% (about 75% practicing), Eastern Orthodox 1%, Protestant and other (2002)
# Christianity
# ==========
# Roman Catholic 94%, Protestant (1995)
# Christianity
# ==========
# Islam 95%
# Islam
# ==========
# Romanian Orthodox 87%, Protestant 8%, Roman Catholic 5%, Islam and other (2002)
# Christianity
# ==========
# Islam (Sunni) 74%; Alawite, Druze, and other Islamic sects 16%; Christian (various sects) 10%; Jewish (tiny communities in Damascus, Al Qamishli, and Aleppo)
# Islam
# ==========
# mixture of Buddhist, Confucian, and Taoist 93%, Christian 4.5%, other 2.5%
# Buddhism
# ==========
# Islam: Sunni 85%, Shiite 5%; other 10% (2003 est.)
# Islam
# ==========
# mainland: Christian 30%, Islam 35%, indigenous 35%; Zanzibar: more than 99% Islam
# Christianity
# ==========
# Buddhist 95%, Islam 5%, Christian 1% (2000)
# Buddhism
# ==========
# Indigenous beliefs 51%, Christian 29%, Islam 20%
# Christianity
# ==========
# Christian (Free Wesleyan Church claims over 30,000 adherents)
# Christianity
# ==========
# Roman Catholic 26%, Anglican 8%, Baptist 7%, Pentecostal 7%, Seventh-Day Adventist 4%, other Christian 6%, Hindu 22%, Islam 6%, none 2%
# Christianity
# ==========
# Islam (Sunni) 98%, Christian 1%, Jewish and other 1%
# Islam
# ==========
# Islam (mostly Sunni) 99.8%, other 0.2% (mostly Christians and Jews)
# Islam
# ==========
# Islam 89%, Eastern Orthodox 9%, unknown 2%
# Islam
# ==========
# Church of Tuvalu (Congregationalist) 97%, Seventh-Day Adventist 1%, Baha'i 1%
# Christianity
# ==========
# Roman Catholic 33%, Protestant 33%, Islam 16%, indigenous beliefs 18%
# Christianity
# ==========
# Ukrainian Orthodox (Kiev Patriarchate 19%, Moscow Patriarchate 9%, no particular division 16%), Ukrainian Greek Catholic 6%, Ukrainian Autocephalous Orthodox 2%, Protestant, Jewish, none 38% (2004)
# Christianity
# ==========
# Islam 96% (Sunni 80%, Shiite 16%), Christian, Hindu, and other 4%
# Islam
# ==========
# Christian (Anglican, Roman Catholic, Presbyterian, Methodist) 71.6%, Muslim 2.7%, Hindu 1%, other 1.6%, unspecified or none 23.1% (2001)
# Christianity
# ==========
# Protestant 52%, Roman Catholic 24%, Mormon 2%, Jewish 1%, Muslim 1%, none 10% (2002)
# Christianity
# ==========
# Roman Catholic 66%, Protestant 2%, Jewish 1%
# Christianity
# ==========
# Islam (mostly Sunnis) 88%, Eastern Orthodox 9%
# Islam
# ==========
# Presbyterian 31%, Anglican 13%, Roman Catholic 13%, Seventh-Day Adventist 11%, other Christian 14%, indigenous beliefs 6% (including Jon Frum Cargo cult), none 1%
# Christianity
# ==========
# Roman Catholic.
# Christianity
# ==========
# Roman Catholic 96%, Protestant 2%
# Christianity
# ==========
# Buddhist 9%, Catholic 7%, Hoa Hao 2%, Cao Dai 1%, Protestant, Islam, none 81%
# Buddhism
# ==========
# Islam
# Islam
# ==========
# Islam (including Sunni and Shiite), small numbers of Jewish, Christian, and Hindu
# Islam
# ==========
# Christian 50%–75%, Islam and Hindu 24%–49%, indigenous beliefs 1%
# Christianity
# ==========
# syncretic (part Christian, part indigenous beliefs) 50%, Christian 25%, indigenous beliefs 24%, Muslim and other 1%
# Christianity

# %%
# fix country names for pycountry
replace_country_names_dic = {"Congo, Democratic Republic of the":"Congo, The Democratic Republic of the",     
                        "Congo, Republic of": "Congo",
                        "Cape Verde":"Cabo Verde",
                        "Palestinian State":"Palestine, State of",
                        "East Timor":"Timor-Leste",
                        "Korea, North":"Korea, Democratic People's Republic of",
                        "Korea, South":"Korea, Republic of",
                        "Laos":"Lao People's Democratic Republic",
                        "So Tom and Prncipe":"Sao Tome and Principe",
                        "Cte d'Ivoire":"Côte d'Ivoire",
                        "Macedonia":"North Macedonia",
                        "Swaziland":"Eswatini"}
# since we cannot change the size of the dictionary withing a loop, save the ones that are supposed
# to be deleted and their replacements
to_delete = []
to_add = {}

# depending on replace_country_names_dic, look at what to replace and what to replace with
for country, religion_list in country_religions.items():
    if country in replace_country_names_dic.keys():
        to_add[replace_country_names_dic[country]] = religion_list
        to_delete.append(country)
        
# delete old names
for country in to_delete:
    del country_religions[country]
    
# add new ones
country_religions = {**country_religions, **to_add}

# manual addition
country_religions["South Sudan"] = "Christianity"
country_religions["China"] = "Buddhism"
country_religions["Sweden"] = "Christianity"
country_religions["Israel"] = "Christianity"

# %% [markdown]
# # Adding Languages and Religions to Dataframe

# %%
# for creating a df
country_name_list = []
country_alpha_2_list = []
country_alpha_3_list = []
languages_list = []
religion_list = []

for country, language_list in country_languages.items():
    # use the pycountry package to obtain the common names, and the alpha2 and alpha3 abbreviations
    pycountry_object = pycountry.countries.search_fuzzy(country)[0]
    country_name_list.append(pycountry_object.name)
    country_alpha_2_list.append(pycountry_object.alpha_2)
    country_alpha_3_list.append(pycountry_object.alpha_3)
    languages_list.append(language_list)
    religion_list.append(country_religions[country])
    
# create it
country_df = pd.DataFrame(list(zip(country_name_list, country_alpha_2_list, country_alpha_3_list, 
                                             languages_list, religion_list)), 
                                   columns =["name", "alpha_2", "alpha_3", "languages", "main_religion"]) 

# save it
country_df.to_pickle("countries.pkl")

# display it
country_df
# Out:
#                                        name alpha_2 alpha_3  \
# 0                               Afghanistan      AF     AFG
# 1                                   Albania      AL     ALB
# 2                                   Algeria      DZ     DZA
# 3                                   Andorra      AD     AND
# 4                                    Angola      AO     AGO
# 5                       Antigua and Barbuda      AG     ATG
# 6                                 Argentina      AR     ARG
# 7                                   Armenia      AM     ARM
# 8                                 Australia      AU     AUS
# 9                                   Austria      AT     AUT
# 10                               Azerbaijan      AZ     AZE
# 11                                  Bahamas      BS     BHS
# 12                                  Bahrain      BH     BHR
# 13                               Bangladesh      BD     BGD
# 14                                 Barbados      BB     BRB
# 15                                  Belarus      BY     BLR
# 16                                  Belgium      BE     BEL
# 17                                   Belize      BZ     BLZ
# 18                                    Benin      BJ     BEN
# 19                                   Bhutan      BT     BTN
# 20          Bolivia, Plurinational State of      BO     BOL
# 21                   Bosnia and Herzegovina      BA     BIH
# 22                                 Botswana      BW     BWA
# 23                                   Brazil      BR     BRA
# 24                        Brunei Darussalam      BN     BRN
# 25                                 Bulgaria      BG     BGR
# 26                             Burkina Faso      BF     BFA
# 27                                  Burundi      BI     BDI
# 28                                 Cambodia      KH     KHM
# 29                                 Cameroon      CM     CMR
# 30                                   Canada      CA     CAN
# 31                 Central African Republic      CF     CAF
# 32                                     Chad      TD     TCD
# 33                                    Chile      CL     CHL
# 34                                    China      CN     CHN
# 35                                 Colombia      CO     COL
# 36                                  Comoros      KM     COM
# 37                               Costa Rica      CR     CRI
# 38                                  Croatia      HR     HRV
# 39                                     Cuba      CU     CUB
# 40                                   Cyprus      CY     CYP
# 41                                  Czechia      CZ     CZE
# 42                                  Denmark      DK     DNK
# 43                                 Djibouti      DJ     DJI
# 44                                 Dominica      DM     DMA
# 45                       Dominican Republic      DO     DOM
# 46                                  Ecuador      EC     ECU
# 47                                    Egypt      EG     EGY
# 48                              El Salvador      SV     SLV
# 49                        Equatorial Guinea      GQ     GNQ
# 50                                  Eritrea      ER     ERI
# 51                                  Estonia      EE     EST
# 52                                 Eswatini      SZ     SWZ
# 53                                 Ethiopia      ET     ETH
# 54                                     Fiji      FJ     FJI
# 55                                  Finland      FI     FIN
# 56                                   France      FR     FRA
# 57                                    Gabon      GA     GAB
# 58                                   Gambia      GM     GMB
# 59                                  Georgia      GE     GEO
# 60                                  Germany      DE     DEU
# 61                                    Ghana      GH     GHA
# 62                                   Greece      GR     GRC
# 63                                  Grenada      GD     GRD
# 64                                Guatemala      GT     GTM
# 65                                   Guinea      GN     GIN
# 66                            Guinea-Bissau      GW     GNB
# 67                                   Guyana      GY     GUY
# 68                                    Haiti      HT     HTI
# 69                                 Honduras      HN     HND
# 70                                  Hungary      HU     HUN
# 71                                  Iceland      IS     ISL
# 72                                    India      IN     IND
# 73                                Indonesia      ID     IDN
# 74                Iran, Islamic Republic of      IR     IRN
# 75                                     Iraq      IQ     IRQ
# 76                                  Ireland      IE     IRL
# 77                                   Israel      IL     ISR
# 78                                    Italy      IT     ITA
# 79                                  Jamaica      JM     JAM
# 80                                    Japan      JP     JPN
# 81                                   Jordan      JO     JOR
# 82                               Kazakhstan      KZ     KAZ
# 83                                    Kenya      KE     KEN
# 84                                 Kiribati      KI     KIR
# 85                                   Kuwait      KW     KWT
# 86                               Kyrgyzstan      KG     KGZ
# 87                                   Latvia      LV     LVA
# 88                                  Lebanon      LB     LBN
# 89                                  Lesotho      LS     LSO
# 90                                  Liberia      LR     LBR
# 91                                    Libya      LY     LBY
# 92                            Liechtenstein      LI     LIE
# 93                                Lithuania      LT     LTU
# 94                               Luxembourg      LU     LUX
# 95                               Madagascar      MG     MDG
# 96                                   Malawi      MW     MWI
# 97                                 Malaysia      MY     MYS
# 98                                 Maldives      MV     MDV
# 99                                     Mali      ML     MLI
# 100                                   Malta      MT     MLT
# 101                        Marshall Islands      MH     MHL
# 102                              Mauritania      MR     MRT
# 103                               Mauritius      MU     MUS
# 104                                  Mexico      MX     MEX
# 105         Micronesia, Federated States of      FM     FSM
# 106                    Moldova, Republic of      MD     MDA
# 107                                  Monaco      MC     MCO
# 108                                Mongolia      MN     MNG
# 109                              Montenegro      ME     MNE
# 110                                 Morocco      MA     MAR
# 111                              Mozambique      MZ     MOZ
# 112                                 Myanmar      MM     MMR
# 113                                 Namibia      NA     NAM
# 114                                   Nauru      NR     NRU
# 115                                   Nepal      NP     NPL
# 116                             Netherlands      NL     NLD
# 117                             New Zealand      NZ     NZL
# 118                               Nicaragua      NI     NIC
# 119                                 Nigeria      NG     NGA
# 120                                 Nigeria      NG     NGA
# 121                         North Macedonia      MK     MKD
# 122                                  Norway      NO     NOR
# 123                                    Oman      OM     OMN
# 124                                Pakistan      PK     PAK
# 125                                   Palau      PW     PLW
# 126                                  Panama      PA     PAN
# 127                        Papua New Guinea      PG     PNG
# 128                                Paraguay      PY     PRY
# 129                                    Peru      PE     PER
# 130                             Philippines      PH     PHL
# 131                                  Poland      PL     POL
# 132                                Portugal      PT     PRT
# 133                                   Qatar      QA     QAT
# 134                                 Romania      RO     ROU
# 135                      Russian Federation      RU     RUS
# 136                                  Rwanda      RW     RWA
# 137                   Saint Kitts and Nevis      KN     KNA
# 138                             Saint Lucia      LC     LCA
# 139        Saint Vincent and the Grenadines      VC     VCT
# 140                                   Samoa      WS     WSM
# 141                              San Marino      SM     SMR
# 142                            Saudi Arabia      SA     SAU
# 143                                 Senegal      SN     SEN
# 144                                  Serbia      RS     SRB
# 145                              Seychelles      SC     SYC
# 146                            Sierra Leone      SL     SLE
# 147                               Singapore      SG     SGP
# 148                                Slovakia      SK     SVK
# 149                                Slovenia      SI     SVN
# 150                         Solomon Islands      SB     SLB
# 151                                 Somalia      SO     SOM
# 152                            South Africa      ZA     ZAF
# 153                             South Sudan      SS     SSD
# 154                                   Spain      ES     ESP
# 155                               Sri Lanka      LK     LKA
# 156                                   Sudan      SD     SDN
# 157                                Suriname      SR     SUR
# 158                                  Sweden      SE     SWE
# 159                             Switzerland      CH     CHE
# 160                    Syrian Arab Republic      SY     SYR
# 161               Taiwan, Province of China      TW     TWN
# 162                              Tajikistan      TJ     TJK
# 163            Tanzania, United Republic of      TZ     TZA
# 164                                Thailand      TH     THA
# 165                                    Togo      TG     TGO
# 166                                   Tonga      TO     TON
# 167                     Trinidad and Tobago      TT     TTO
# 168                                 Tunisia      TN     TUN
# 169                                  Turkey      TR     TUR
# 170                            Turkmenistan      TM     TKM
# 171                                  Tuvalu      TV     TUV
# 172                                  Uganda      UG     UGA
# 173                                 Ukraine      UA     UKR
# 174                    United Arab Emirates      AE     ARE
# 175                          United Kingdom      GB     GBR
# 176                           United States      US     USA
# 177                                 Uruguay      UY     URY
# 178                              Uzbekistan      UZ     UZB
# 179                                 Vanuatu      VU     VUT
# 180           Holy See (Vatican City State)      VA     VAT
# 181       Venezuela, Bolivarian Republic of      VE     VEN
# 182                                Viet Nam      VN     VNM
# 183                          Western Sahara      EH     ESH
# 184                                   Yemen      YE     YEM
# 185                                  Zambia      ZM     ZMB
# 186                                Zimbabwe      ZW     ZWE
# 187                              Cabo Verde      CV     CPV
# 188   Congo, The Democratic Republic of the      CD     COD
# 189                                   Congo      CG     COG
# 190                           Côte d'Ivoire      CI     CIV
